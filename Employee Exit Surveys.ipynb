# %% [markdown]
# # Clean and Analyze Employee Exit Surveys

# %% [markdown]
# In this guided project, we'll work with exit surveys from employees of the Department of Education, Training and Employment (DETE) and the Technical and Further Education (TAFE) institute in Queensland, Australia. We want to know the following:
#
# Are employees who only worked for the institutes for a short period of time resigning due to some kind of dissatisfaction? What about employees who have been there longer?
#
# Are younger employees resigning due to some kind of dissatisfaction? What about older employees?

# %%
import pandas as pd
import numpy as np

# %%
dete_survey = pd.read_csv("dete_survey.csv")
tafe_survey = pd.read_csv("tafe_survey.csv")

# %%
print(dete_survey.shape)
dete_survey.info()
# Out:
# (822, 56)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 822 entries, 0 to 821
# Data columns (total 56 columns):
# ID                                     822 non-null int64
# SeparationType                         822 non-null object
# Cease Date                             822 non-null object
# DETE Start Date                        822 non-null object
# Role Start Date                        822 non-null object
# Position                               817 non-null object
# Classification                         455 non-null object
# Region                                 822 non-null object
# Business Unit                          126 non-null object
# Employment Status                      817 non-null object
# Career move to public sector           822 non-null bool
# Career move to private sector          822 non-null bool
# Interpersonal conflicts                822 non-null bool
# Job dissatisfaction                    822 non-null bool
# ...

# %%
dete_survey.head(3)
# Out:
#    ID                    SeparationType Cease Date DETE Start Date  \
# 0   1             Ill Health Retirement    08/2012            1984
# 1   2  Voluntary Early Retirement (VER)    08/2012      Not Stated
# 2   3  Voluntary Early Retirement (VER)    05/2012            2011
#
#   Role Start Date         Position Classification          Region  \
# 0            2004   Public Servant        A01-A04  Central Office
# 1      Not Stated   Public Servant        AO5-AO7  Central Office
# 2            2011  Schools Officer            NaN  Central Office
#
#                        Business Unit    Employment Status  ...   \
# 0  Corporate Strategy and Peformance  Permanent Full-time  ...
# 1  Corporate Strategy and Peformance  Permanent Full-time  ...
# 2               Education Queensland  Permanent Full-time  ...
#
#    Kept informed  Wellness programs  Health & Safety  Gender          Age  \
# 0              N                  N                N    Male        56-60
# ...

# %%
dete_survey.isnull().sum()
# Out:
# ID                                       0
# SeparationType                           0
# Cease Date                               0
# DETE Start Date                          0
# Role Start Date                          0
# Position                                 5
# Classification                         367
# Region                                   0
# Business Unit                          696
# Employment Status                        5
# Career move to public sector             0
# Career move to private sector            0
# Interpersonal conflicts                  0
# Job dissatisfaction                      0
# Dissatisfaction with the department      0
# Physical work environment                0
# Lack of recognition                      0
# Lack of job security                     0
# Work location                            0
# Employment conditions                    0
# Maternity/family                         0
# Relocation                               0
# ...

# %%
dete_survey.dtypes.head()
# Out:
# ID                  int64
# SeparationType     object
# Cease Date         object
# DETE Start Date    object
# Role Start Date    object
# dtype: object

# %%
dete_survey.columns
# Out:
# Index(['ID', 'SeparationType', 'Cease Date', 'DETE Start Date',
#        'Role Start Date', 'Position', 'Classification', 'Region',
#        'Business Unit', 'Employment Status', 'Career move to public sector',
#        'Career move to private sector', 'Interpersonal conflicts',
#        'Job dissatisfaction', 'Dissatisfaction with the department',
#        'Physical work environment', 'Lack of recognition',
#        'Lack of job security', 'Work location', 'Employment conditions',
#        'Maternity/family', 'Relocation', 'Study/Travel', 'Ill Health',
#        'Traumatic incident', 'Work life balance', 'Workload',
#        'None of the above', 'Professional Development',
#        'Opportunities for promotion', 'Staff morale', 'Workplace issue',
#        'Physical environment', 'Worklife balance',
#        'Stress and pressure support', 'Performance of supervisor',
#        'Peer support', 'Initiative', 'Skills', 'Coach', 'Career Aspirations',
# ...

# %%
dete_survey["SeparationType"].value_counts()
# Out:
# Age Retirement                          285
# Resignation-Other reasons               150
# Resignation-Other employer               91
# Resignation-Move overseas/interstate     70
# Voluntary Early Retirement (VER)         67
# Ill Health Retirement                    61
# Other                                    49
# Contract Expired                         34
# Termination                              15
# Name: SeparationType, dtype: int64

# %%
dete_survey[["SeparationType","Cease Date","DETE Start Date"]]
# Out:
#                            SeparationType  Cease Date DETE Start Date
# 0                   Ill Health Retirement     08/2012            1984
# 1        Voluntary Early Retirement (VER)     08/2012      Not Stated
# 2        Voluntary Early Retirement (VER)     05/2012            2011
# 3               Resignation-Other reasons     05/2012            2005
# 4                          Age Retirement     05/2012            1970
# 5               Resignation-Other reasons     05/2012            1994
# 6                          Age Retirement     05/2012            1972
# 7                          Age Retirement     05/2012            1988
# 8               Resignation-Other reasons     07/2012            2009
# 9              Resignation-Other employer        2012            1997
# 10                         Age Retirement        2012            1999
# 11   Resignation-Move overseas/interstate        2012            2009
# ...

# %%
dete_survey["Cease Date"].dtype
# Out:
# dtype('O')

# %%
dete_survey["DETE Start Date"].dtype
# Out:
# dtype('O')

# %%
dete_survey["Gender"].value_counts(dropna=False)
# Out:
# Female    573
# Male      225
# NaN        24
# Name: Gender, dtype: int64

# %%
tafe_survey.head(3)
# Out:
#       Record ID                              Institute  \
# 0  6.341330e+17  Southern Queensland Institute of TAFE
# 1  6.341337e+17            Mount Isa Institute of TAFE
# 2  6.341388e+17            Mount Isa Institute of TAFE
#
#                    WorkArea  CESSATION YEAR Reason for ceasing employment  \
# 0  Non-Delivery (corporate)          2010.0              Contract Expired
# 1  Non-Delivery (corporate)          2010.0                    Retirement
# 2       Delivery (teaching)          2010.0                    Retirement
#
#   Contributing Factors. Career Move - Public Sector   \
# 0                                                NaN
# 1                                                  -
# 2                                                  -
#
#   Contributing Factors. Career Move - Private Sector   \
# 0                                                NaN
# 1                                                  -
# 2                                                  -
#
# ...

# %%
print(tafe_survey.shape)
tafe_survey.isnull().sum()
# Out:
# (702, 72)
# Record ID                                                                                                                                                          0
# Institute                                                                                                                                                          0
# WorkArea                                                                                                                                                           0
# CESSATION YEAR                                                                                                                                                     7
# Reason for ceasing employment                                                                                                                                      1
# ...

# %%
tafe_survey["Reason for ceasing employment"].value_counts()
# Out:
# Resignation                 340
# Contract Expired            127
# Retrenchment/ Redundancy    104
# Retirement                   82
# Transfer                     25
# Termination                  23
# Name: Reason for ceasing employment, dtype: int64

# %%
tafe_survey.head(2)
# Out:
#       Record ID                              Institute  \
# 0  6.341330e+17  Southern Queensland Institute of TAFE
# 1  6.341337e+17            Mount Isa Institute of TAFE
#
#                    WorkArea  CESSATION YEAR Reason for ceasing employment  \
# 0  Non-Delivery (corporate)          2010.0              Contract Expired
# 1  Non-Delivery (corporate)          2010.0                    Retirement
#
#   Contributing Factors. Career Move - Public Sector   \
# 0                                                NaN
# 1                                                  -
#
#   Contributing Factors. Career Move - Private Sector   \
# 0                                                NaN
# 1                                                  -
#
#   Contributing Factors. Career Move - Self-employment  \
# 0                                                NaN
# 1                                                  -
#
#   Contributing Factors. Ill Health Contributing Factors. Maternity/Family  \
# ...

# %%
dete_survey.head(2)
# Out:
#    ID                    SeparationType Cease Date DETE Start Date  \
# 0   1             Ill Health Retirement    08/2012            1984
# 1   2  Voluntary Early Retirement (VER)    08/2012      Not Stated
#
#   Role Start Date        Position Classification          Region  \
# 0            2004  Public Servant        A01-A04  Central Office
# 1      Not Stated  Public Servant        AO5-AO7  Central Office
#
#                        Business Unit    Employment Status  ...   \
# 0  Corporate Strategy and Peformance  Permanent Full-time  ...
# 1  Corporate Strategy and Peformance  Permanent Full-time  ...
#
#    Kept informed  Wellness programs  Health & Safety  Gender    Age  \
# 0              N                  N                N    Male  56-60
# 1              N                  N                N    Male  56-60
#
#    Aboriginal  Torres Strait  South Sea  Disability  NESB
# 0         NaN            NaN        NaN         NaN   Yes
# ...

# %%
tafe_survey["Reason for ceasing employment"].value_counts()
# Out:
# Resignation                 340
# Contract Expired            127
# Retrenchment/ Redundancy    104
# Retirement                   82
# Transfer                     25
# Termination                  23
# Name: Reason for ceasing employment, dtype: int64

# %%
dete_survey["SeparationType"].value_counts()
# Out:
# Age Retirement                          285
# Resignation-Other reasons               150
# Resignation-Other employer               91
# Resignation-Move overseas/interstate     70
# Voluntary Early Retirement (VER)         67
# Ill Health Retirement                    61
# Other                                    49
# Contract Expired                         34
# Termination                              15
# Name: SeparationType, dtype: int64

# %%
dete_survey = pd.read_csv("dete_survey.csv",na_values="Not Stated")

# %%
dete_survey.head()
# Out:
#    ID                    SeparationType Cease Date  DETE Start Date  \
# 0   1             Ill Health Retirement    08/2012           1984.0
# 1   2  Voluntary Early Retirement (VER)    08/2012              NaN
# 2   3  Voluntary Early Retirement (VER)    05/2012           2011.0
# 3   4         Resignation-Other reasons    05/2012           2005.0
# 4   5                    Age Retirement    05/2012           1970.0
#
#    Role Start Date                                      Position  \
# 0           2004.0                                Public Servant
# 1              NaN                                Public Servant
# 2           2011.0                               Schools Officer
# 3           2006.0                                       Teacher
# 4           1989.0  Head of Curriculum/Head of Special Education
#
#   Classification              Region                      Business Unit  \
# 0        A01-A04      Central Office  Corporate Strategy and Peformance
# ...

# %%
dete_survey_columns_to_drop = dete_survey.iloc[:,28:49]

# %%
dete_survey_updated = dete_survey.drop(dete_survey_columns_to_drop,axis=1)

# %%
dete_survey_updated.head(2)
# Out:
#    ID                    SeparationType Cease Date  DETE Start Date  \
# 0   1             Ill Health Retirement    08/2012           1984.0
# 1   2  Voluntary Early Retirement (VER)    08/2012              NaN
#
#    Role Start Date        Position Classification          Region  \
# 0           2004.0  Public Servant        A01-A04  Central Office
# 1              NaN  Public Servant        AO5-AO7  Central Office
#
#                        Business Unit    Employment Status  ...   \
# 0  Corporate Strategy and Peformance  Permanent Full-time  ...
# 1  Corporate Strategy and Peformance  Permanent Full-time  ...
#
#    Work life balance  Workload  None of the above  Gender    Age  Aboriginal  \
# 0              False     False               True    Male  56-60         NaN
# 1              False     False              False    Male  56-60         NaN
#
#    Torres Strait  South Sea  Disability  NESB
# 0            NaN        NaN         NaN   Yes
# ...

# %%
tafe_survey_columns_to_drop = tafe_survey.iloc[:,17:66]

# %%
tafe_survey_updated = tafe_survey.drop(tafe_survey_columns_to_drop,axis=1)

# %%
tafe_survey_updated.head(3)
# Out:
#       Record ID                              Institute  \
# 0  6.341330e+17  Southern Queensland Institute of TAFE
# 1  6.341337e+17            Mount Isa Institute of TAFE
# 2  6.341388e+17            Mount Isa Institute of TAFE
#
#                    WorkArea  CESSATION YEAR Reason for ceasing employment  \
# 0  Non-Delivery (corporate)          2010.0              Contract Expired
# 1  Non-Delivery (corporate)          2010.0                    Retirement
# 2       Delivery (teaching)          2010.0                    Retirement
#
#   Contributing Factors. Career Move - Public Sector   \
# 0                                                NaN
# 1                                                  -
# 2                                                  -
#
#   Contributing Factors. Career Move - Private Sector   \
# 0                                                NaN
# 1                                                  -
# 2                                                  -
#
# ...

# %%
dete_survey_updated.columns
# Out:
# Index(['ID', 'SeparationType', 'Cease Date', 'DETE Start Date',
#        'Role Start Date', 'Position', 'Classification', 'Region',
#        'Business Unit', 'Employment Status', 'Career move to public sector',
#        'Career move to private sector', 'Interpersonal conflicts',
#        'Job dissatisfaction', 'Dissatisfaction with the department',
#        'Physical work environment', 'Lack of recognition',
#        'Lack of job security', 'Work location', 'Employment conditions',
#        'Maternity/family', 'Relocation', 'Study/Travel', 'Ill Health',
#        'Traumatic incident', 'Work life balance', 'Workload',
#        'None of the above', 'Gender', 'Age', 'Aboriginal', 'Torres Strait',
#        'South Sea', 'Disability', 'NESB'],
#       dtype='object')

# %%
tafe_survey_updated.columns
# Out:
# Index(['Record ID', 'Institute', 'WorkArea', 'CESSATION YEAR',
#        'Reason for ceasing employment',
#        'Contributing Factors. Career Move - Public Sector ',
#        'Contributing Factors. Career Move - Private Sector ',
#        'Contributing Factors. Career Move - Self-employment',
#        'Contributing Factors. Ill Health',
#        'Contributing Factors. Maternity/Family',
#        'Contributing Factors. Dissatisfaction',
#        'Contributing Factors. Job Dissatisfaction',
#        'Contributing Factors. Interpersonal Conflict',
#        'Contributing Factors. Study', 'Contributing Factors. Travel',
#        'Contributing Factors. Other', 'Contributing Factors. NONE',
#        'Gender. What is your Gender?', 'CurrentAge. Current Age',
#        'Employment Type. Employment Type', 'Classification. Classification',
#        'LengthofServiceOverall. Overall Length of Service at Institute (in years)',
# ...

# %%
dete_survey_updated.columns = dete_survey_updated.columns.str.lower().str.replace(" ","_").str.strip()

# %%
dete_survey_updated.head(1)
# Out:
#    id         separationtype cease_date  dete_start_date  role_start_date  \
# 0   1  Ill Health Retirement    08/2012           1984.0           2004.0
#
#          position classification          region  \
# 0  Public Servant        A01-A04  Central Office
#
#                        business_unit    employment_status  ...   \
# 0  Corporate Strategy and Peformance  Permanent Full-time  ...
#
#    work_life_balance  workload  none_of_the_above  gender    age  aboriginal  \
# 0              False     False               True    Male  56-60         NaN
#
#    torres_strait  south_sea  disability  nesb
# 0            NaN        NaN         NaN   Yes
#
# [1 rows x 35 columns]

# %%
tafe_survey_updated.head(1)
# Out:
#       Record ID                              Institute  \
# 0  6.341330e+17  Southern Queensland Institute of TAFE
#
#                    WorkArea  CESSATION YEAR Reason for ceasing employment  \
# 0  Non-Delivery (corporate)          2010.0              Contract Expired
#
#   Contributing Factors. Career Move - Public Sector   \
# 0                                                NaN
#
#   Contributing Factors. Career Move - Private Sector   \
# 0                                                NaN
#
#   Contributing Factors. Career Move - Self-employment  \
# 0                                                NaN
#
#   Contributing Factors. Ill Health Contributing Factors. Maternity/Family  \
# 0                              NaN                                    NaN
#
#                                      ...                                     \
# 0                                    ...
#
#   Contributing Factors. Study Contributing Factors. Travel  \
# ...

# %%
tafe_survey_renamed_columns = {"Record ID": "id", "CESSATION YEAR":"cease_date","Gender. What is your Gender?":"gender",
                              "CurrentAge. Current Age":"age", "Employment Type. Employment Type":"employment_status",
                              "Classification. Classification":"position",
                              "LengthofServiceOverall. Overall Length of Service at Institute (in years)": "institute_service",
                              "LengthofServiceCurrent. Length of Service at current workplace (in years)": "role_service",
                              "Reason for ceasing employment":"separationtype"}

# %%
tafe_survey_updated.rename(tafe_survey_renamed_columns,axis=1,inplace=True)

# %%
tafe_survey_updated.head(2)
# Out:
#              id                              Institute  \
# 0  6.341330e+17  Southern Queensland Institute of TAFE
# 1  6.341337e+17            Mount Isa Institute of TAFE
#
#                    WorkArea  cease_date    separationtype  \
# 0  Non-Delivery (corporate)      2010.0  Contract Expired
# 1  Non-Delivery (corporate)      2010.0        Retirement
#
#   Contributing Factors. Career Move - Public Sector   \
# 0                                                NaN
# 1                                                  -
#
#   Contributing Factors. Career Move - Private Sector   \
# 0                                                NaN
# 1                                                  -
#
#   Contributing Factors. Career Move - Self-employment  \
# 0                                                NaN
# 1                                                  -
#
#   Contributing Factors. Ill Health Contributing Factors. Maternity/Family  \
# ...

# %%
dete_survey_updated.head(1)
# Out:
#    id         separationtype cease_date  dete_start_date  role_start_date  \
# 0   1  Ill Health Retirement    08/2012           1984.0           2004.0
#
#          position classification          region  \
# 0  Public Servant        A01-A04  Central Office
#
#                        business_unit    employment_status  ...   \
# 0  Corporate Strategy and Peformance  Permanent Full-time  ...
#
#    work_life_balance  workload  none_of_the_above  gender    age  aboriginal  \
# 0              False     False               True    Male  56-60         NaN
#
#    torres_strait  south_sea  disability  nesb
# 0            NaN        NaN         NaN   Yes
#
# [1 rows x 35 columns]

# %%
tafe_survey_updated.head(1)
# Out:
#              id                              Institute  \
# 0  6.341330e+17  Southern Queensland Institute of TAFE
#
#                    WorkArea  cease_date    separationtype  \
# 0  Non-Delivery (corporate)      2010.0  Contract Expired
#
#   Contributing Factors. Career Move - Public Sector   \
# 0                                                NaN
#
#   Contributing Factors. Career Move - Private Sector   \
# 0                                                NaN
#
#   Contributing Factors. Career Move - Self-employment  \
# 0                                                NaN
#
#   Contributing Factors. Ill Health Contributing Factors. Maternity/Family  \
# 0                              NaN                                    NaN
#
#       ...      Contributing Factors. Study Contributing Factors. Travel  \
# 0     ...                              NaN                          NaN
#
#   Contributing Factors. Other Contributing Factors. NONE  gender     age  \
# ...

# %%
dete_survey_updated["separationtype"].value_counts()
# Out:
# Age Retirement                          285
# Resignation-Other reasons               150
# Resignation-Other employer               91
# Resignation-Move overseas/interstate     70
# Voluntary Early Retirement (VER)         67
# Ill Health Retirement                    61
# Other                                    49
# Contract Expired                         34
# Termination                              15
# Name: separationtype, dtype: int64

# %%
tafe_survey_updated["separationtype"].value_counts()
# Out:
# Resignation                 340
# Contract Expired            127
# Retrenchment/ Redundancy    104
# Retirement                   82
# Transfer                     25
# Termination                  23
# Name: separationtype, dtype: int64

# %%
tafe_survey_updated[tafe_survey_updated["separationtype"] == "Resignation"].shape
# Out:
# (340, 23)

# %%
dete_survey_updated["separationtype"].value_counts()
# Out:
# Age Retirement                          285
# Resignation-Other reasons               150
# Resignation-Other employer               91
# Resignation-Move overseas/interstate     70
# Voluntary Early Retirement (VER)         67
# Ill Health Retirement                    61
# Other                                    49
# Contract Expired                         34
# Termination                              15
# Name: separationtype, dtype: int64

# %%
mapping_resignations = {"Resignation-Other reasons":"Resignation",
                       "Resignation-Other employer":"Resignation",
                       "Resignation-Other employer":"Resignation",
                       "Resignation-Move overseas/interstate":"Resignation"}

# %%
dete_survey_updated["separationtype"] = dete_survey_updated["separationtype"].str.split("-").str[0]

# %%
dete_survey_updated["separationtype"].value_counts()
# Out:
# Resignation                         311
# Age Retirement                      285
# Voluntary Early Retirement (VER)     67
# Ill Health Retirement                61
# Other                                49
# Contract Expired                     34
# Termination                          15
# Name: separationtype, dtype: int64

# %%
dete_resignations = dete_survey_updated[dete_survey_updated["separationtype"]=="Resignation"].copy()

# %%
dete_resignations.shape
# Out:
# (311, 35)

# %%
tafe_resignations = tafe_survey_updated[tafe_survey_updated["separationtype"]=="Resignation"].copy()

# %%
tafe_resignations.shape
# Out:
# (340, 23)

# %%
dete_resignations.head(1)
# Out:
#    id separationtype cease_date  dete_start_date  role_start_date position  \
# 3   4    Resignation    05/2012           2005.0           2006.0  Teacher
#
#   classification              region business_unit    employment_status  ...   \
# 3        Primary  Central Queensland           NaN  Permanent Full-time  ...
#
#    work_life_balance  workload  none_of_the_above  gender    age  aboriginal  \
# 3              False     False              False  Female  36-40         NaN
#
#    torres_strait  south_sea  disability  nesb
# 3            NaN        NaN         NaN   NaN
#
# [1 rows x 35 columns]

# %%
tafe_resignations.head(1)
# Out:
#              id                    Institute                  WorkArea  \
# 3  6.341399e+17  Mount Isa Institute of TAFE  Non-Delivery (corporate)
#
#    cease_date separationtype  \
# 3      2010.0    Resignation
#
#   Contributing Factors. Career Move - Public Sector   \
# 3                                                  -
#
#   Contributing Factors. Career Move - Private Sector   \
# 3                                                  -
#
#   Contributing Factors. Career Move - Self-employment  \
# 3                                                  -
#
#   Contributing Factors. Ill Health Contributing Factors. Maternity/Family  \
# 3                                -                                      -
#
#       ...      Contributing Factors. Study Contributing Factors. Travel  \
# 3     ...                                -                       Travel
#
#   Contributing Factors. Other Contributing Factors. NONE gender  age  \
# ...

# %%
dete_resignations["cease_date"].dtype
# Out:
# dtype('O')

# %%
dete_resignations["dete_start_date"].dtype
# Out:
# dtype('float64')

# %%
dete_resignations["cease_date"] = dete_resignations["cease_date"].str.split("/").str[-1]

# %%
dete_resignations["cease_date"] = dete_resignations["cease_date"].astype(float)

# %%
dete_resignations["cease_date"].value_counts()
# Out:
# 2013.0    146
# 2012.0    129
# 2014.0     22
# 2010.0      2
# 2006.0      1
# Name: cease_date, dtype: int64

# %%
dete_resignations["dete_start_date"].value_counts().sort_index()
# Out:
# 1963.0     1
# 1971.0     1
# 1972.0     1
# 1973.0     1
# 1974.0     2
# 1975.0     1
# 1976.0     2
# 1977.0     1
# 1980.0     5
# 1982.0     1
# 1983.0     2
# 1984.0     1
# 1985.0     3
# 1986.0     3
# 1987.0     1
# 1988.0     4
# 1989.0     4
# 1990.0     5
# 1991.0     4
# 1992.0     6
# 1993.0     5
# 1994.0     6
# 1995.0     4
# 1996.0     6
# 1997.0     5
# 1998.0     6
# 1999.0     8
# 2000.0     9
# 2001.0     3
# 2002.0     6
# 2003.0     6
# 2004.0    14
# 2005.0    15
# 2006.0    13
# 2007.0    21
# 2008.0    22
# 2009.0    13
# 2010.0    17
# 2011.0    24
# 2012.0    21
# 2013.0    10
# Name: dete_start_date, dtype: int64

# %%
tafe_resignations["cease_date"].value_counts()
# Out:
# 2011.0    116
# 2012.0     94
# 2010.0     68
# 2013.0     55
# 2009.0      2
# Name: cease_date, dtype: int64

# %%
tafe_resignations.head(1)
# Out:
#              id                    Institute                  WorkArea  \
# 3  6.341399e+17  Mount Isa Institute of TAFE  Non-Delivery (corporate)
#
#    cease_date separationtype  \
# 3      2010.0    Resignation
#
#   Contributing Factors. Career Move - Public Sector   \
# 3                                                  -
#
#   Contributing Factors. Career Move - Private Sector   \
# 3                                                  -
#
#   Contributing Factors. Career Move - Self-employment  \
# 3                                                  -
#
#   Contributing Factors. Ill Health Contributing Factors. Maternity/Family  \
# 3                                -                                      -
#
#       ...      Contributing Factors. Study Contributing Factors. Travel  \
# 3     ...                                -                       Travel
#
#   Contributing Factors. Other Contributing Factors. NONE gender  age  \
# ...

# %% [markdown]
# The years in both dataframes don't completely align. The tafe_survey_updated dataframe contains some cease dates in 2009, but the dete_survey_updated dataframe does not. The tafe_survey_updated dataframe also contains many more cease dates in 2010 than the dete_survey_updaed dataframe. Since we aren't concerned with analyzing the results by year, we'll leave them as is.

# %%
tafe_resignations["institute_service"].value_counts()
# Out:
# Less than 1 year      73
# 1-2                   64
# 3-4                   63
# 5-6                   33
# 11-20                 26
# 7-10                  21
# More than 20 years    10
# Name: institute_service, dtype: int64

# %%
dete_resignations["institute_service"] = dete_resignations["cease_date"] - dete_resignations["dete_start_date"]

# %%
dete_resignations["institute_service"].head()
# Out:
# 3      7.0
# 5     18.0
# 8      3.0
# 9     15.0
# 11     3.0
# Name: institute_service, dtype: float64

# %%
tafe_resignations["Contributing Factors. Job Dissatisfaction"].value_counts()
# Out:
# -                      270
# Job Dissatisfaction     62
# Name: Contributing Factors. Job Dissatisfaction, dtype: int64

# %%
dete_resignations[["id","dete_start_date","cease_date","job_dissatisfaction","dissatisfaction_with_the_department"]]
# Out:
#       id  dete_start_date  cease_date  job_dissatisfaction  \
# 3      4           2005.0      2012.0                False
# 5      6           1994.0      2012.0                False
# 8      9           2009.0      2012.0                False
# 9     10           1997.0      2012.0                 True
# 11    12           2009.0      2012.0                False
# 12    13           1998.0      2012.0                False
# 14    15           2007.0      2012.0                 True
# 16    17              NaN      2012.0                False
# 20    21           1982.0      2012.0                False
# 21    22           1980.0      2012.0                False
# 22    23           1997.0      2012.0                False
# 23    24           1973.0      2012.0                 True
# 25    26           1995.0      2012.0                False
# 27    28           2005.0      2012.0                False
# 33    34           2003.0      2012.0                False
# ...

# %%
tafe_resignations.columns
# Out:
# Index(['id', 'Institute', 'WorkArea', 'cease_date', 'separationtype',
#        'Contributing Factors. Career Move - Public Sector ',
#        'Contributing Factors. Career Move - Private Sector ',
#        'Contributing Factors. Career Move - Self-employment',
#        'Contributing Factors. Ill Health',
#        'Contributing Factors. Maternity/Family',
#        'Contributing Factors. Dissatisfaction',
#        'Contributing Factors. Job Dissatisfaction',
#        'Contributing Factors. Interpersonal Conflict',
#        'Contributing Factors. Study', 'Contributing Factors. Travel',
#        'Contributing Factors. Other', 'Contributing Factors. NONE', 'gender',
#        'age', 'employment_status', 'position', 'institute_service',
#        'role_service'],
#       dtype='object')

# %%
tafe_resignations[["cease_date","Contributing Factors. Dissatisfaction",
                  "Contributing Factors. Job Dissatisfaction"]]
# Out:
#      cease_date   Contributing Factors. Dissatisfaction  \
# 3        2010.0                                       -
# 4        2010.0                                       -
# 5        2010.0                                       -
# 6        2010.0                                       -
# 7        2010.0                                       -
# 8        2009.0                                       -
# 9        2010.0                                       -
# 10       2010.0                                       -
# 13       2010.0                                       -
# 14       2010.0  Contributing Factors. Dissatisfaction
# 15       2010.0                                       -
# 16       2010.0                                     NaN
# 17       2010.0                                       -
# 18       2010.0                                     NaN
# 19       2010.0                                       -
# 20       2010.0  Contributing Factors. Dissatisfaction
# ...

# %%
tafe_resignations["Contributing Factors. Dissatisfaction"].value_counts(dropna=False)
# Out:
# -                                         277
# Contributing Factors. Dissatisfaction      55
# NaN                                         8
# Name: Contributing Factors. Dissatisfaction, dtype: int64

# %%
tafe_resignations["Contributing Factors. Job Dissatisfaction"].value_counts(dropna=False)
# Out:
# -                      270
# Job Dissatisfaction     62
# NaN                      8
# Name: Contributing Factors. Job Dissatisfaction, dtype: int64

# %%
def update_dissatisfactions(x):
    if x == "-":
        return False
    elif pd.isnull(x):
        return np.nan
    else:
        return True

# %%
tafe_resignations["dissatisfied"] = tafe_resignations[["Contributing Factors. Dissatisfaction",
                                                      "Contributing Factors. Job Dissatisfaction"]].applymap(update_dissatisfactions).any(1, skipna=False)

# %%
tafe_resignations["dissatisfied"].value_counts(dropna=False)
# Out:
# False    241
# True      91
# NaN        8
# Name: dissatisfied, dtype: int64

# %%
dete_resignations.columns
# Out:
# Index(['id', 'separationtype', 'cease_date', 'dete_start_date',
#        'role_start_date', 'position', 'classification', 'region',
#        'business_unit', 'employment_status', 'career_move_to_public_sector',
#        'career_move_to_private_sector', 'interpersonal_conflicts',
#        'job_dissatisfaction', 'dissatisfaction_with_the_department',
#        'physical_work_environment', 'lack_of_recognition',
#        'lack_of_job_security', 'work_location', 'employment_conditions',
#        'maternity/family', 'relocation', 'study/travel', 'ill_health',
#        'traumatic_incident', 'work_life_balance', 'workload',
#        'none_of_the_above', 'gender', 'age', 'aboriginal', 'torres_strait',
#        'south_sea', 'disability', 'nesb', 'institute_service'],
#       dtype='object')

# %%
dete_dissatisfactions = ["job_dissatisfaction","dissatisfaction_with_the_department",
                        "physical_work_environment","lack_of_recognition",
                        "lack_of_job_security","work_location","employment_conditions",
                        "work_life_balance","workload"]

# %%
dete_resignations["dissatisfied"] = dete_resignations[dete_dissatisfactions].applymap(update_dissatisfactions).any(1,skipna=False)

# %%
dete_resignations['dissatisfied'] = dete_resignations[['job_dissatisfaction',
       'dissatisfaction_with_the_department', 'physical_work_environment',
       'lack_of_recognition', 'lack_of_job_security', 'work_location',
       'employment_conditions', 'work_life_balance',
       'workload']].any(1, skipna=False)

# %%
dete_resignations["dissatisfied"].value_counts(dropna=False)
# Out:
# False    162
# True     149
# Name: dissatisfied, dtype: int64

# %%
dete_resignations_up = dete_resignations.copy()

# %%
tafe_resignations_up = tafe_resignations.copy()

# %%
print(dete_resignations_up.shape)
dete_resignations_up.head(2)
# Out:
# (311, 37)
#    id separationtype  cease_date  dete_start_date  role_start_date  \
# 3   4    Resignation      2012.0           2005.0           2006.0
# 5   6    Resignation      2012.0           1994.0           1997.0
#
#            position classification              region         business_unit  \
# 3           Teacher        Primary  Central Queensland                   NaN
# 5  Guidance Officer            NaN      Central Office  Education Queensland
#
#      employment_status      ...       none_of_the_above  gender    age  \
# 3  Permanent Full-time      ...                   False  Female  36-40
# 5  Permanent Full-time      ...                   False  Female  41-45
#
#    aboriginal  torres_strait  south_sea  disability  nesb  institute_service  \
# 3         NaN            NaN        NaN         NaN   NaN                7.0
# 5         NaN            NaN        NaN         NaN   NaN               18.0
#
#    dissatisfied
# 3         False
# 5          True
#
# ...

# %%
print(tafe_resignations_up.shape)
tafe_resignations_up.head(2)
# Out:
# (340, 24)
#              id                              Institute  \
# 3  6.341399e+17            Mount Isa Institute of TAFE
# 4  6.341466e+17  Southern Queensland Institute of TAFE
#
#                    WorkArea  cease_date separationtype  \
# 3  Non-Delivery (corporate)      2010.0    Resignation
# 4       Delivery (teaching)      2010.0    Resignation
#
#   Contributing Factors. Career Move - Public Sector   \
# 3                                                  -
# 4                                                  -
#
#   Contributing Factors. Career Move - Private Sector   \
# 3                                                  -
# 4                       Career Move - Private Sector
#
#   Contributing Factors. Career Move - Self-employment  \
# 3                                                  -
# 4                                                  -
#
#   Contributing Factors. Ill Health Contributing Factors. Maternity/Family  \
# ...

# %%
dete_resignations_up["institute"] = "DETE"

# %%
tafe_resignations_up["institute"] = "TAFE"

# %%
combine = pd.concat([dete_resignations_up,tafe_resignations_up],ignore_index=True)

# %%
combine.head(1)
# Out:
#   Contributing Factors. Career Move - Private Sector   \
# 0                                                NaN
#
#   Contributing Factors. Career Move - Public Sector   \
# 0                                                NaN
#
#   Contributing Factors. Career Move - Self-employment  \
# 0                                                NaN
#
#   Contributing Factors. Dissatisfaction Contributing Factors. Ill Health  \
# 0                                   NaN                              NaN
#
#   Contributing Factors. Interpersonal Conflict  \
# 0                                          NaN
#
#   Contributing Factors. Job Dissatisfaction  \
# 0                                       NaN
#
#   Contributing Factors. Maternity/Family Contributing Factors. NONE  \
# 0                                    NaN                        NaN
#
#   Contributing Factors. Other    ...    role_service role_start_date  \
# 0                         NaN    ...             NaN          2006.0
#
# ...

# %%
combined_updated = combine.dropna(axis=1,thresh=500).copy()

# %%
combined_updated.notnull().sum()
# Out:
# age                  596
# cease_date           635
# dissatisfied         643
# employment_status    597
# gender               592
# id                   651
# institute            651
# institute_service    563
# position             598
# separationtype       651
# dtype: int64

# %%
combined_updated.columns
# Out:
# Index(['age', 'cease_date', 'dissatisfied', 'employment_status', 'gender',
#        'id', 'institute', 'institute_service', 'position', 'separationtype'],
#       dtype='object')

# %%
combined_updated["institute_service"].value_counts()
# Out:
# Less than 1 year      73
# 1-2                   64
# 3-4                   63
# 5-6                   33
# 11-20                 26
# 5.0                   23
# 1.0                   22
# 7-10                  21
# 3.0                   20
# 0.0                   20
# 6.0                   17
# 4.0                   16
# 9.0                   14
# 2.0                   14
# 7.0                   13
# More than 20 years    10
# 13.0                   8
# 8.0                    8
# 20.0                   7
# 15.0                   7
# 14.0                   6
# 17.0                   6
# 12.0                   6
# 10.0                   6
# 22.0                   6
# 18.0                   5
# 16.0                   5
# 24.0                   4
# 23.0                   4
# 11.0                   4
# 19.0                   3
# 39.0                   3
# 21.0                   3
# 32.0                   3
# 36.0                   2
# 25.0                   2
# 26.0                   2
# ...

# %%
combined_updated["institute_service"] = combined_updated["institute_service"].astype(str)

# %%
combined_updated["institute_service"].head()
# Out:
# 0     7.0
# 1    18.0
# 2     3.0
# 3    15.0
# 4     3.0
# Name: institute_service, dtype: object

# %%
extract_pattern = r"(\d+)"

# %%
combined_updated["institute_service"] = combined_updated["institute_service"].str.extract(extract_pattern)
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/ipykernel/__main__.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   if __name__ == '__main__':

# %%
combined_updated["institute_service"] = combined_updated["institute_service"].astype(float)

# %%
combined_updated.head(2)
# Out:
#      age  cease_date dissatisfied    employment_status  gender   id institute  \
# 0  36-40      2012.0        False  Permanent Full-time  Female  4.0      DETE
# 1  41-45      2012.0         True  Permanent Full-time  Female  6.0      DETE
#
#   institute_service          position separationtype
# 0       Established           Teacher    Resignation
# 1               New  Guidance Officer    Resignation

# %%
def service_cat(age):
    if age >= 11:
        return "Veteran"
    elif 7 <= age < 11:
        return "Established"
    elif 3 <= age < 7:
        return "Experienced"
    elif pd.isnull(age):
        return np.nan
    else:
        return "New"

# %%
combined_updated["institute_service"].value_counts()
# Out:
# New            329
# Experienced    172
# Established     62
# Name: institute_service, dtype: int64
